# %% [markdown]
# # Projet 2

# %%
# import des modules usuels
import numpy as np
import pandas as pd

# options d'affichage
pd.set_option("display.min_rows", 16)

# %%
# chargement et traitement des données
geo = pd.read_csv("correspondance-code-insee-code-postal.csv",
                   sep=';',
                   usecols=range(11),
                   index_col="Code INSEE")
geo = geo.sort_index()
geo[['Latitude', 'Longitude']] = geo["geo_point_2d"].str.extract("(.*), (.*)").astype(float)
geo.head()
# Out:
#            Code Postal                  Commune Département       Région  \
# Code INSEE
# 01001            01400  L'ABERGEMENT-CLEMENCIAT         AIN  RHONE-ALPES
# 01002            01640    L'ABERGEMENT-DE-VAREY         AIN  RHONE-ALPES
# 01004            01500        AMBERIEU-EN-BUGEY         AIN  RHONE-ALPES
# 01005            01330      AMBERIEUX-EN-DOMBES         AIN  RHONE-ALPES
# 01006            01300                  AMBLEON         AIN  RHONE-ALPES
#
#                       Statut  Altitude Moyenne  Superficie  Population  \
# Code INSEE
# 01001         Commune simple             242.0      1565.0         0.8
# 01002         Commune simple             483.0       912.0         0.2
# 01004       Chef-lieu canton             379.0      2448.0        13.4
# 01005         Commune simple             290.0      1605.0         1.6
# 01006         Commune simple             589.0       602.0         0.1
#
#                             geo_point_2d  \
# Code INSEE
# ...

# %% [markdown]
# **Projet maison n° 1**
#
# - Ajoutez une colonne 'CP Ville' avec le Code postal + un espace + et le nom de la Ville.
# - Ecrivez une fonction qui détermine la commune la plus proche d'un point à partir de sa latitude et sa longitude.
# - Ajoutez une fonction de conversion pour pouvoir utiliser la première fonction avec un GPS (degrés, minutes, secondes).

# %%
geo['CP Ville'] = geo['Code Postal']+ ' ' +geo['Commune'] 
geo.head()
# Out:
#            Code Postal                  Commune Département       Région  \
# Code INSEE
# 01001            01400  L'ABERGEMENT-CLEMENCIAT         AIN  RHONE-ALPES
# 01002            01640    L'ABERGEMENT-DE-VAREY         AIN  RHONE-ALPES
# 01004            01500        AMBERIEU-EN-BUGEY         AIN  RHONE-ALPES
# 01005            01330      AMBERIEUX-EN-DOMBES         AIN  RHONE-ALPES
# 01006            01300                  AMBLEON         AIN  RHONE-ALPES
#
#                       Statut  Altitude Moyenne  Superficie  Population  \
# Code INSEE
# 01001         Commune simple             242.0      1565.0         0.8
# 01002         Commune simple             483.0       912.0         0.2
# 01004       Chef-lieu canton             379.0      2448.0        13.4
# 01005         Commune simple             290.0      1605.0         1.6
# 01006         Commune simple             589.0       602.0         0.1
#
#                             geo_point_2d  \
# Code INSEE
# ...

# %%
# fonction recherche de ville

def ville(lat, long):
    geoprime = geo.copy()
    geoprime['distance minimale'] = geo.apply(lambda g:(g['Latitude'] - lat)**2 + (g['Longitude'] - long)**2, axis=1)
    return geo.loc[geoprime['distance minimale'].idxmin()]
 #pass
    
    
print(ville(5,5))
# Out:
# Code Postal                                                     20169
# Commune                                                     BONIFACIO
# Département                                              CORSE-DU-SUD
# Région                                                          CORSE
# Statut                                               Chef-lieu canton
# Altitude Moyenne                                                 95.0
# Superficie                                                    14096.0
# Population                                                        2.9
# geo_point_2d                             41.4354987425, 9.18514890376
# geo_shape           {"type": "MultiPolygon", "coordinates": [[[[9....
# Latitude                                                    41.435499
# Longitude                                                    9.185149
# CP Ville                                              20169 BONIFACIO
# Name: 2A041, dtype: object

# %%
# conversion degrés, minutes, secondes => décimal
def dms2dec(deg, mn, sec):
    return deg + mn / 60 + sec / 3600

# %%
# on applique la fonction à une coordonnée tirée au hasard
# init du random
np.random.seed(0)

a, b = 41.5, 51.1  # latitude min et max de la France métropolitaine
lat = (b - a) * np.random.random() + a
a, b = -5.1, 9.5  # longitude min et max de la France métropolitaine
long = (b - a) * np.random.random() + a

ville(lat, long)
# Out:
# Code Postal                                                     71330
# Commune                                                       BOSJEAN
# Département                                            SAONE-ET-LOIRE
# Région                                                      BOURGOGNE
# Statut                                                 Commune simple
# Altitude Moyenne                                                202.0
# Superficie                                                     1862.0
# Population                                                        0.3
# geo_point_2d                             46.7696786287, 5.34727924927
# geo_shape           {"type": "Polygon", "coordinates": [[[5.345021...
# Latitude                                                    46.769679
# Longitude                                                    5.347279
# CP Ville                                                71330 BOSJEAN
# Name: 71044, dtype: object

# %%
# à partir de coordonnées GPS précises
ville(dms2dec(48, 42, 52), dms2dec(2, 14, 45))
# Out:
# Code Postal                                                     91120
# Commune                                                     PALAISEAU
# Département                                                   ESSONNE
# Région                                                  ILE-DE-FRANCE
# Statut                                                Sous-préfecture
# Altitude Moyenne                                                118.0
# Superficie                                                     1168.0
# Population                                                       30.3
# geo_point_2d                             48.7146765876, 2.22881488083
# geo_shape           {"type": "Polygon", "coordinates": [[[2.259350...
# Latitude                                                    48.714677
# Longitude                                                    2.228815
# CP Ville                                              91120 PALAISEAU
# Name: 91477, dtype: object

# %% [markdown]
# **Projet maison n° 2**
#
# La colonne "geo_shape" comporte des chaines de catactères au format JSON. Elles représentent les formes géométriques des communes qui sont soit des polygones soit composées de plusieurs polygones.
#
# - Utiliser la librairie Python json pour parser la colonne "geo_shape".
# - Donner le décompte des valeurs accédées avec la clé "type".
# - Donner le décompte des longueurs des listes accédées avec la clé "coordinates".
# - Quelle commune est la plus complexe géométriquement ?
# - Quelle commune est la seconde la plus complexe géométriquement ?
# - Quelles sont les villes qui sont de type "Polygon" mais dont la longueur des listes accédées avec la clé "coordinates" vaut 2 ?
# - Pour ces villes vérifier que le premier polygone contient bien le second (enclave). NB : installer la librairie shapely, utiliser la classe Polygon de shapely.geometry. Sur Windows shapely peut nécessiter d'installer la dll "geos_c.dll" dans le répertoire "Library/bin" de votre environnement Python.

# %%
import json

geo['geo_shape'].apply(lambda g: json.loads(g))
                         
geo.head()
# Out:
#            Code Postal                  Commune Département       Région  \
# Code INSEE
# 01001            01400  L'ABERGEMENT-CLEMENCIAT         AIN  RHONE-ALPES
# 01002            01640    L'ABERGEMENT-DE-VAREY         AIN  RHONE-ALPES
# 01004            01500        AMBERIEU-EN-BUGEY         AIN  RHONE-ALPES
# 01005            01330      AMBERIEUX-EN-DOMBES         AIN  RHONE-ALPES
# 01006            01300                  AMBLEON         AIN  RHONE-ALPES
#
#                       Statut  Altitude Moyenne  Superficie  Population  \
# Code INSEE
# 01001         Commune simple             242.0      1565.0         0.8
# 01002         Commune simple             483.0       912.0         0.2
# 01004       Chef-lieu canton             379.0      2448.0        13.4
# 01005         Commune simple             290.0      1605.0         1.6
# 01006         Commune simple             589.0       602.0         0.1
#
#                             geo_point_2d  \
# Code INSEE
# ...

# %%
geo['type']= (geo['geo_shape'].apply(lambda g: json.loads(g))).apply(lambda i: i['type'])
geo['type'].value_counts()
# Out:
# Polygon         36670
# MultiPolygon       72
# Name: type, dtype: int64

# %%
geometrie_V = geo['geo_shape'].apply(lambda x: json.loads(x))
geo['coordinates'] = geometrie_V.apply(lambda x: x['coordinates'])
coord = geo['coordinates'].apply(lambda g:len(g[0]))
coord.sort_values()
# Out:
# Code INSEE
# 11286      1
# 39279      1
# 27701      1
# 86161      1
# 57554      1
# 63048      1
# 2A041      1
# 22198      1
#         ...
# 97308    203
# 97352    226
# 97358    251
# 97311    273
# 97356    325
# 97306    334
# 97301    392
# 97353    486
# Name: coordinates, Length: 36742, dtype: int64

# %%
geo['Commune'].loc[geo['coordinates'].apply(lambda i:len(i[0])).idxmax()]
# Out:
# 'MARIPASOULA'

# %%
geo['Commune'].loc[coord.sort_values(ascending=False).index[1]]
# Out:
# 'REGINA'

# %%
geo[(geo['type'] == 'Polygon') & (geo['coordinates'] == 2)]
# Out:
# Empty DataFrame
# Columns: [Code Postal, Commune, Département, Région, Statut, Altitude Moyenne, Superficie, Population, geo_point_2d, geo_shape, Latitude, Longitude, CP Ville, type, coordinates]
# Index: []
